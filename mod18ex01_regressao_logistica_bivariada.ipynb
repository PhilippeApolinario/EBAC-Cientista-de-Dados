# %% [markdown]
# # Regressão Logística I
# ## Tarefa I
#
# Neste exercício vamos trabalhar com a base "Heart Disease Data Set" disponível no site do [UCI](https://archive.ics.uci.edu/ml/datasets/heart+disease).
#
# Temos 303 indivíduos e vamos utilizar 13 variáveis disponíveis para prever a presença de doença cardíaca na variável ```num```(a 14$^a$ variável).
#
# A descrição das variáveis está recortada abaixo:
# - age: idade do paciente em anos
# - sex: sexo (1 = male; 0 = female)
# - cp: tipo de dor no peito
#   - 1: angina típica
#   - 2: angina atípica
#   - 3: dor não-angina
#   - 4: assintomático
# - trestbps: pressão sanguínea em repouso (em mm Hg na admissão ao hospital
# - chol: colesterol sérico em mg/dl
# - fbs: (açúcar no sangue em jejum > 120 mg/dl) (1 = True; 0 = False)
# - restecg: resultados eletrocardiográficos em repouso
#   - 0: normal
#   - 1: tendo anormalidade da onda ST-T (Inversões de onda T e / ou ST com elevação ou depressão de > 0.05 mV)
#   - 2: mostrando hipertrofia ventricular esquerda provável ou definitiva pelos critérios de Estes
# - thalach: frequência cardíaca máxima alcançada
# - exang: angina induzida por exercício(1 = sim; 0 = não)
# - oldpeak = Depressão de ST induzida por exercício em relação ao repouso
# - slope: Depressão de ST induzida por exercício em relação ao repouso
#   - 1: inclinação ascendente
#   - 2: estável
#   - 3: inclinação descendente
# - ca: número de vasos principais (0-3) coloridos por fluorosopia
# - thal: 3 = normal; 6 = defeito corrigido; 7 = defeito reversível
# - num: diagnóstico de doença cardíaga (status de doença angiográfica)

# %%
# Versão da Linguagem Python
from platform import python_version
print('Versão da Linguagem Python Usada Neste Jupyter Notebook:', python_version())
# Out:
# Versão da Linguagem Python Usada Neste Jupyter Notebook: 3.9.13

# %%
# Imports
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import statsmodels.formula.api as smf

# %%
# Versões dos pacotes usados neste jupyter notebook
# %reload_ext watermark
# %watermark --iversions
# Out:
# numpy      : 1.21.5
# matplotlib : 3.5.2
# statsmodels: 0.13.2
# pandas     : 1.4.4
# seaborn    : 0.11.2

# %%
# Carregando dados
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.cleveland.data'

df = pd.read_csv(url, 
                 names=['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg',
                        'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'num'])
df.head()
# Out:
#     age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0  63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1  67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2  67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3  37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4  41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
#
#    slope   ca thal  num
# 0    3.0  0.0  6.0    0
# 1    2.0  3.0  3.0    2
# 2    2.0  2.0  7.0    1
# 3    3.0  0.0  3.0    0
# 4    1.0  0.0  3.0    0

# %%
# Adiciona uma nova coluna chamada "flag_doente" (1 para doente e 0 para saudável)
df['flag_doente'] = (df['num'] != 0).astype('int64')
df
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1    67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2    67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3    37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4    41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
# ..    ...  ...  ...       ...    ...  ...      ...      ...    ...      ...
# 298  45.0  1.0  1.0     110.0  264.0  0.0      0.0    132.0    0.0      1.2
# 299  68.0  1.0  4.0     144.0  193.0  1.0      0.0    141.0    0.0      3.4
# 300  57.0  1.0  4.0     130.0  131.0  0.0      0.0    115.0    1.0      1.2
# 301  57.0  0.0  2.0     130.0  236.0  0.0      2.0    174.0    0.0      0.0
# 302  38.0  1.0  3.0     138.0  175.0  0.0      0.0    173.0    0.0      0.0
#
#      slope   ca thal  num  flag_doente
# ...

# %% [markdown]
# 1. Monte uma bivariada para a variável ```sex``` com as seguintes estatísticas:
#
# - Número de *saudáveis*
# - Número de *doentes*
# - Total
# - Quantidade média de doentes
# - *Odds*
# - *Odds ratio* (Use o total como referência)
# - Logito (LOG(*Odds*))
# - O LOG do *Odds ratio* (com o total como referência) é chamado de *Weight of Evidence* (WOE). Calcule-o.

# %%
# Alterando 0/1 para dados categóricos
df['sex'].replace({0: 'feminino', 1: 'masculino'}, inplace=True)
df['flag_doente'].replace({0: 'saudaveis', 1: 'doentes'}, inplace=True)

# %%
# Crosstab sex e flag_doentes com total
tab = pd.crosstab(df['sex'], df['flag_doente'], margins=True)

# Quantidade media de doentes
tab['percentual_doentes'] = tab['doentes'] / tab['All']

# Odds
tab['odds_doentes'] = tab['doentes']/tab['saudaveis']

# Odds ratio
tab['odds_ratio'] = tab['odds_doentes'] / tab.loc['All', 'odds_doentes']

# logito
tab['logito_doentes'] = np.log(tab['odds_doentes'])

# WOE (log odds ratio)
tab['woe'] = np.log(tab['odds_ratio'])

tab
# Out:
# flag_doente  doentes  saudaveis  All  percentual_doentes  odds_doentes  \
# sex
# feminino          25         72   97            0.257732      0.347222
# masculino        114         92  206            0.553398      1.239130
# All              139        164  303            0.458746      0.847561
#
# flag_doente  odds_ratio  logito_doentes       woe
# sex
# feminino       0.409672       -1.057790 -0.892398
# masculino      1.461996        0.214410  0.379802
# All            1.000000       -0.165392  0.000000

# %% [markdown]
# 2. Monte uma bivariada para a variável ```age``` com as seguintes estatísticas:
# - Categorize a variável em 5 grupos
# - Calcule as mesmas quantidades calculadas no execício anterior
# - Calcule também o valor médio da variável ```age```

# %%
# Idade mínima
df.age.min()
# Out:
# 29.0

# %%
# Idade máxima
df.age.max()
# Out:
# 77.0

# %%
# Média de idade
df.age.mean()
# Out:
# 54.43894389438944

# %%
# Agrupando em 5 grupos de 10
bins = [28, 38, 48, 58, 68, 78]
labels = ['28 a 37 anos', '38 a 47 anos', '48 a 57 anos', '58 a 67 anos', '68 a 77 anos']

df['age_group'] = pd.cut(df['age'], bins = bins, labels = labels, right = False)

# %%
# Crosstab age e flag_doentes com total
tab = pd.crosstab(df['age_group'], df['flag_doente'], margins = True)

# Quantidae media de doentes
tab['percentual_doentes'] = tab['doentes'] / tab['All']

# Odds
tab['Odds_doentes'] = tab['percentual_doentes'] / (1 - tab['percentual_doentes'])

# Odds ratio
tab['Odds_ratio'] = tab['Odds_doentes']/tab.loc['All','Odds_doentes']

# Logito
tab['Logito_doentes'] = np.log(tab['Odds_doentes'])
# WOE (log odds ratio)
tab['WOE'] = np.log(tab['Odds_ratio'])
tab
# Out:
# flag_doente   doentes  saudaveis  All  percentual_doentes  Odds_doentes  \
# age_group
# 28 a 37 anos        2          7    9            0.222222      0.285714
# 38 a 47 anos       19         47   66            0.287879      0.404255
# 48 a 57 anos       44         60  104            0.423077      0.733333
# 58 a 67 anos       67         40  107            0.626168      1.675000
# 68 a 77 anos        7         10   17            0.411765      0.700000
# All               139        164  303            0.458746      0.847561
#
# flag_doente   Odds_ratio  Logito_doentes       WOE
# age_group
# 28 a 37 anos    0.337102       -1.252763 -1.087370
# 38 a 47 anos    0.476963       -0.905709 -0.740316
# 48 a 57 anos    0.865228       -0.310155 -0.144762
# 58 a 67 anos    1.976259        0.515813  0.681206
# 68 a 77 anos    0.825899       -0.356675 -0.191282
# All             1.000000       -0.165392  0.000000

# %% [markdown]
# 3. Visualize a informação da bivariada construída acima através de um gráfico da sua escolha.

# %%
# Criando uma copia e dropando a coluna 'All'
tab_copy = tab
tab_copy = tab_copy.drop('All')

# %%
sns.set_theme(style='darkgrid')

# %%
# Transformando dados
df_plot = tab_copy[['doentes', 'saudaveis']].reset_index()
df_plot = df_plot.melt(id_vars=['age_group'], var_name='estado', value_name='contagem')

fig, ax = plt.subplots(figsize=(10, 5)) 

sns.barplot(x='age_group', y='contagem', hue='estado', data=df_plot)

plt.title('Número de Pessoas Doentes e Saudáveis por Grupo de Idade')
plt.xlabel('Grupo de Idade')
plt.ylabel('Número de Pessoas')

plt.show()

# %%
# Transformando dados
df_plot = tab[['percentual_doentes', 'Odds_doentes', 'Odds_ratio', 'Logito_doentes', 'WOE']].reset_index()
df_plot = pd.melt(df_plot, id_vars=['age_group'], var_name='medida', value_name='valor')

fig, ax = plt.subplots(figsize=(10, 5)) 
sns.barplot(x='age_group', y='valor', hue='medida', data=df_plot)

plt.title('Medidas estatísticas por Grupo de Idade')
plt.xlabel('Grupo de Idade')
plt.ylabel('Valor')

plt.show()
