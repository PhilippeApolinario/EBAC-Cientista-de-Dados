# %% [markdown]
# # Módulo 07, Tarefa 01
#
# Vamos começar a mexer na nossa base de projeto? Já fizemos um exercício de montar a variável resposta, já pudemos perceber que essa atividade pode não ser trivial. Vamos agora trabalhar a base para que fique propícia ao *scikitlearn* para trabalharmos.
#
# Lembrando, a base se chama demo01.csv, e originalmente está publicada [aqui](https://www.kaggle.com/rikdifos/credit-card-approval-prediction).

# %%
# Versão da Linguagem Python
from platform import python_version
print('Versão da Linguagem Python Usada Neste Jupyter Notebook:', python_version())
# Out:
# Versão da Linguagem Python Usada Neste Jupyter Notebook: 3.9.13

# %%
# Imports

# Manipulação de dados
import pandas as pd
import numpy as np

# Visualização
import seaborn as sns

# %%
# Versões dos pacotes usados neste jupyter notebook
# %reload_ext watermark
# %watermark --iversions
# Out:
# pandas : 1.4.4
# seaborn: 0.11.2
# numpy  : 1.21.5

# %% [markdown]
# #### 1) Carregue a base e avalie:
#
# - As variáveis
# - Tipos de dados de cada variável
# - Quantidade de missings
# - Distribuição da variável resposta (mau)

# %%
# Carrega o dataset
df = pd.read_csv('Demo 01.csv')

# %%
# Shape
df.shape
# Out:
# (16650, 16)

# %%
# Colunas
df.columns
# Out:
# Index(['sexo', 'posse_de_veiculo', 'posse_de_imovel', 'qtd_filhos',
#        'tipo_renda', 'educacao', 'estado_civil', 'tipo_residencia', 'idade',
#        'tempo_emprego', 'possui_celular', 'possui_fone_comercial',
#        'possui_fone', 'possui_email', 'qt_pessoas_residencia', 'mau'],
#       dtype='object')

# %%
# Amostra dos dados
df.head()
# Out:
#   sexo posse_de_veiculo posse_de_imovel  qtd_filhos            tipo_renda  \
# 0    M                Y               Y           0               Working
# 1    F                N               Y           0  Commercial associate
# 2    F                N               Y           0  Commercial associate
# 3    M                Y               Y           0               Working
# 4    F                Y               N           0               Working
#
#                         educacao          estado_civil    tipo_residencia  \
# 0  Secondary / secondary special               Married  House / apartment
# 1  Secondary / secondary special  Single / not married  House / apartment
# 2  Secondary / secondary special  Single / not married  House / apartment
# 3               Higher education               Married  House / apartment
# 4              Incomplete higher               Married  House / apartment
#
#        idade  tempo_emprego  possui_celular  possui_fone_comercial  \
# ...

# %%
# Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16650 entries, 0 to 16649
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   sexo                   16650 non-null  object
#  1   posse_de_veiculo       16650 non-null  object
#  2   posse_de_imovel        16650 non-null  object
#  3   qtd_filhos             16650 non-null  int64
#  4   tipo_renda             16650 non-null  object
#  5   educacao               16650 non-null  object
#  6   estado_civil           16650 non-null  object
#  7   tipo_residencia        16650 non-null  object
#  8   idade                  16650 non-null  float64
#  9   tempo_emprego          16650 non-null  float64
#  10  possui_celular         16650 non-null  int64
#  11  possui_fone_comercial  16650 non-null  int64
#  12  possui_fone            16650 non-null  int64
#  13  possui_email           16650 non-null  int64
# ...

# %% [markdown]
# ### Análise Exploratória

# %%
# Descrevendo os dados não numéricos
df.describe(include = object)
# Out:
#          sexo posse_de_veiculo posse_de_imovel tipo_renda  \
# count   16650            16650           16650      16650
# unique      2                2               2          5
# top         F                N               Y    Working
# freq    11201            10178           11176       8565
#
#                              educacao estado_civil    tipo_residencia
# count                           16650        16650              16650
# unique                              5            5                  6
# top     Secondary / secondary special      Married  House / apartment
# freq                            11245        11680              14974

# %%
# Descrevendo os dados numéricos
df.describe()
# Out:
#          qtd_filhos         idade  tempo_emprego  possui_celular  \
# count  16650.000000  16650.000000   16650.000000         16650.0
# mean       0.433153     44.319513    -161.416446             1.0
# std        0.739395     11.228837     376.843912             0.0
# min        0.000000     22.030137   -1000.665753             1.0
# 25%        0.000000     34.873973       1.183562             1.0
# 50%        0.000000     43.493151       4.691781             1.0
# 75%        1.000000     53.410959       9.088356             1.0
# max       14.000000     68.909589      42.906849             1.0
#
#        possui_fone_comercial   possui_fone  possui_email  \
# count           16650.000000  16650.000000  16650.000000
# mean                0.225225      0.295676      0.088889
# std                 0.417743      0.456360      0.284592
# min                 0.000000      0.000000      0.000000
# 25%                 0.000000      0.000000      0.000000
# ...

# %% [markdown]
# ### Identificando Valores Duplicados

# %%
# Idenficando  duplicados
df.duplicated().sum()
# Out:
# 9880

# %%
# Removendo dados duplicados
df = df.drop_duplicates()
df.shape
# Out:
# (6770, 16)

# %%
# Reset de Index
df.reset_index(drop=True, inplace=True)
df.tail()
# Out:
#      sexo posse_de_veiculo posse_de_imovel  qtd_filhos            tipo_renda  \
# 6765    F                N               Y           1               Working
# 6766    F                N               Y           0               Working
# 6767    F                N               Y           0  Commercial associate
# 6768    M                Y               Y           0               Working
# 6769    F                N               Y           0             Pensioner
#
#                            educacao          estado_civil    tipo_residencia  \
# 6765  Secondary / secondary special  Single / not married  House / apartment
# 6766  Secondary / secondary special        Civil marriage  House / apartment
# 6767  Secondary / secondary special               Married  House / apartment
# 6768  Secondary / secondary special               Married  House / apartment
# 6769               Higher education               Married  House / apartment
#
# ...

# %%
# Quantidade de missings
df.isna().sum()
# Out:
# sexo                     0
# posse_de_veiculo         0
# posse_de_imovel          0
# qtd_filhos               0
# tipo_renda               0
# educacao                 0
# estado_civil             0
# tipo_residencia          0
# idade                    0
# tempo_emprego            0
# possui_celular           0
# possui_fone_comercial    0
# possui_fone              0
# possui_email             0
# qt_pessoas_residencia    0
# mau                      0
# dtype: int64

# %%
# Distribuição da variável resposta (mau)
df['mau'].value_counts()
# Out:
# False    6472
# True      298
# Name: mau, dtype: int64

# %%
# Contagens de frequência relativa em percentuais
round(df['mau'].value_counts(normalize=True)*100,2)
# Out:
# False    95.6
# True      4.4
# Name: mau, dtype: float64

# %% [markdown]
# #### 2) Vamos montar um metadados
#
# 1. Crie um dataframe com os nomes de cada variável e o tipo de dados de cada variável.
# 2. Adicione uma coluna nesse *dataframe* chamada "qtd_categorias" e coloque nela o número de categorias correspondente de cada variável.
#     Dica:
#         1. inicie uma lista vazia
#         2. faça um for ao longo dos nomes das variáveis,
#         3. conte o número de categorias dessa variável
#         4. acumule essa informação de 3. na lista que você criou em 1.
#         5. No final, essa lista pode ser atribuída à nossa variável.
# 3. Crie variáveis dummy para as variáveis necessárias (i.e. aquelas que são qualitativas e não estão armazenadas como {0, 1} ou {True, False}.

# %%
# 1.Crie um dataframe com os nomes de cada variável e o tipo de dados de cada variável.
df_colunas = pd.DataFrame(df.dtypes, columns = ['tipo_variavel'])

df.head()
# Out:
#   sexo posse_de_veiculo posse_de_imovel  qtd_filhos            tipo_renda  \
# 0    M                Y               Y           0               Working
# 1    F                N               Y           0  Commercial associate
# 2    M                Y               Y           0               Working
# 3    F                Y               N           0               Working
# 4    F                N               Y           0               Working
#
#                         educacao          estado_civil    tipo_residencia  \
# 0  Secondary / secondary special               Married  House / apartment
# 1  Secondary / secondary special  Single / not married  House / apartment
# 2               Higher education               Married  House / apartment
# 3              Incomplete higher               Married  House / apartment
# 4  Secondary / secondary special               Married  House / apartment
#
#        idade  tempo_emprego  possui_celular  possui_fone_comercial  \
# ...

# %%
# 2.Adicione uma coluna nesse dataframe chamada "qtd_categorias" 
# e coloque nela o número de categorias correspondente de cada variável.

df_colunas['qtd_categorias'] = 0

for var in df_colunas.index:
    df_colunas.loc[var,'qtd_categorias'] = len(df.groupby([var]).size())
    
df_colunas
# Out:
#                       tipo_variavel  qtd_categorias
# sexo                         object               2
# posse_de_veiculo             object               2
# posse_de_imovel              object               2
# qtd_filhos                    int64               8
# tipo_renda                   object               5
# educacao                     object               5
# estado_civil                 object               5
# tipo_residencia              object               6
# idade                       float64            5298
# tempo_emprego               float64            3005
# possui_celular                int64               1
# possui_fone_comercial         int64               2
# possui_fone                   int64               2
# possui_email                  int64               2
# qt_pessoas_residencia       float64               9
# mau                            bool               2

# %%
# Criando variáveis Dummies para as variáveis "tipo_renda", "educacao", "estado_civil", "tipo_residencia"
df_encoded = pd.get_dummies(df, columns=['tipo_renda','educacao','estado_civil','tipo_residencia'], drop_first=True)

# %% [markdown]
# #### 3) Crie variáveis dummy para as variáveis necessárias (i.e. aquelas que são qualitativas e não estão armazenadas como {0, 1} ou {True, False}. Crie um *dataframe* apenas com as variáveis apropriadas para entrada no scikitlearn - elimine as variáveis tipo *str*, mantendo apenas suas versões *dummy*.

# %%
# Especificando como os valores categóricos serão mapeados para valores numéricos.
df_encoded['sexo'] = df_encoded.sexo.map({'F': 1, 'M':0})
df_encoded['posse_de_veiculo'] = df_encoded.posse_de_veiculo.map({'Y': 1, 'N':0})
df_encoded['posse_de_imovel'] = df_encoded.posse_de_imovel.map({'Y': 1, 'N':0})


df_encoded.head()
# Out:
#    sexo  posse_de_veiculo  posse_de_imovel  qtd_filhos      idade  \
# 0     0                 1                1           0  58.832877
# 1     1                 0                1           0  52.356164
# 2     0                 1                1           0  46.224658
# 3     1                 1                0           0  29.230137
# 4     1                 0                1           0  27.482192
#
#    tempo_emprego  possui_celular  possui_fone_comercial  possui_fone  \
# 0       3.106849               1                      0            0
# 1       8.358904               1                      0            1
# 2       2.106849               1                      1            1
# 3       3.021918               1                      0            0
# 4       4.024658               1                      0            1
#
#    possui_email  ...  educacao_Secondary / secondary special  \
# 0             0  ...                                       1
# ...

# %% [markdown]
# #### 4) Qual variável é mais poderosa?
#
# Considere as variáveis ```possui_email``` e ```posse_de_veiculo```. Faça uma tabela cruzada entre elas e responda qual delas te parece mais poderosa para prever a probabilidade de ```mau = 1```?

# %%
tab_a = pd.crosstab(df['possui_email'], df['mau'])
tab_a.div(tab_a.sum(axis=1), axis=0)
# Out:
# mau              False      True
# possui_email
# 0             0.955197  0.044803
# 1             0.964602  0.035398

# %%
tab_b = pd.crosstab(df['posse_de_veiculo'], df['mau'])
tab_b.div(tab_b.sum(axis=1), axis=0)
# Out:
# mau                  False      True
# posse_de_veiculo
# N                 0.954880  0.045120
# Y                 0.957796  0.042204

# %% [markdown]
# __Conclusão:__ Para prever a probabilidade de mau=1 a variável 'posse_de_veículo' é a mais poderosa, pois a condição de possuir veículo apresenta maior numeros de eventos do que a condição de possuir e-mail.

# %% [markdown]
# #### 5) Salve a base, pois ela será utilizada no final deste módulo.

# %%
df_encoded.to_csv('demo01_encoded.csv')
